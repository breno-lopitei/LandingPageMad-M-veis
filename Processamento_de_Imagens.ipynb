# %% [markdown]
# <a href="https://colab.research.google.com/github/breno-lopitei/LandingPageMad-M-veis/blob/main/Processamento_de_Imagens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Imagem Colorida x Imagem em Tons de Cinza**

# %%
import numpy as np
import cv2
from skimage import io
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
origem = "https://raw.githubusercontent.com/scikit-image/scikit-image/v0.19.0/skimage/data/astronaut.png"
img_original = io.imread(origem)
img_cinza = cv2.cvtColor(img_original, cv2.COLOR_RGB2GRAY)

# %%
fig, ax = plt.subplots(1, 2,
figsize=(10, 6))
fig.tight_layout()
ax[0].imshow(cv2.cvtColor(img_original,
cv2.COLOR_BGR2RGB))
ax[0].set_title("Original")
ax[1].imshow(cv2.cvtColor(img_cinza,
cv2.COLOR_BGR2RGB))
ax[1].set_title("Tons de Cinza")
plt.show()
